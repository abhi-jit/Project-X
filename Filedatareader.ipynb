# %%
import csv
from pandas import DataFrame
ifile  = open('LEAD_PUR_TAB.csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
datanew = []
for row in read :
    i = i+1
    datanew.append(row)

# Printing the 1st element of list of list
print(datanew[0])

# Convert list of list to dataframe
purchase = DataFrame.from_records(datanew)

# Shape of Purchase
print(purchase.shape)
# Out:
# ['ETO_LEAD_PUR_ID', 'FK_GLUSR_USR_ID', 'ETO_PUR_DATE', 'FK_ETO_OFR_ID', 'ETO_CREDITS_USED', 'ETO_OFR_GLUSR_USR_ID', 'ETO_LEAD_FK_GL_MODULE_ID', 'ETO_LEAD_PUR_KEYWORD', 'ETO_LEAD_PUR_LAPSE_MSG', 'ETO_LEAD_PUR_MAIL_SENT', 'ETO_LEAD_SENT_THISTOMAIL', 'ETO_LEAD_PUR_IP', 'ETO_LEAD_PUR_IP_COUNTRY', 'ETO_LEAD_PUR_MODE', 'ETO_LEAD_PUR_IP_CITY', 'FK_ETO_AFL_ID', 'ETO_LEAD_PUR_AFL_SHARE', 'FK_ETO_AFL_PAYMENT_ID', 'ETO_LEAD_PUR_AFL_REV_SHARE', 'FK_ETO_OFR_DATE', 'ETO_AFL_CRD_REV_FLAG', 'ETO_LEAD_PUR_POSITION', 'ETO_LEAD_PUR_POSITION_URL', 'ETO_LEAD_PUR_TYPE', 'ETO_LEAD_PUR_READ_STATUS', 'ETO_LEAD_PUR_READ_DATE', 'ETO_LEAD_PUR_GA_VISITOR_ID', 'ETO_LEAD_CREDITS_AV', 'ETO_LEAD_PUR_CUST_SEGMENT', 'ETO_CUST_TYPE_WEIGHT', 'ETO_CUST_SEGMENT', 'ETO_LEAD_PUR_FIRST_READ_DATE', 'ETO_CREDITS_USED_LEADCNT', '']
# (519317, 34)

# %%
import csv
ifile  = open('OFR_DATA_PART2 (2).csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>2):
        break
# Out:
# ['ETO_OFR_DISPLAY_ID', 'FK_GLUSR_USR_ID', 'ETO_OFR_DATE', 'ETO_OFR_LATITUDE', 'ETO_OFR_LONGITUDE', 'ETO_OFR_CALL_RECORDING_URL', 'ETO_OFR_CALL_DISPOSITION_TYPE', 'ETO_OFR_GEOGRAPHY_ID', 'ETO_OFR_GEOGRAPHY_NAME', 'ETO_OFR_CALL_DISPOSITION_ID', 'ETO_OFR_PROD_SERV', 'ETO_OFR_TITLE', 'ETO_OFR_EXP_DATE', 'ETO_OFR_SPEC', 'ETO_OFR_QTY', 'FK_GL_CONTINENT_ID', 'ETO_OFR_APPROV_DATE', 'ETO_OFR_DELETIONDATE', 'ETO_OFR_DELBYADMINORUSER', 'ETO_OFR_DELETEDBYID', 'ETO_OFR_CALL_DATE', 'FK_GL_COUNTRY_ISO', 'FK_GL_MODULE_ID', 'OFR_MCAT_NAME', 'OFR_CAT_NAME', '']
#
#
# ['15397384063', '22724754', '12-JUL-2017 15:29:05', '19.191477', '72.82576', 'http://182.75.225.82/leaplink/LEAP_AUTO_NEW_ANKITKUMAR83_2038_9819563327_527_3802279_20170710_172608_A071020171725510003802279.mp3', 'Validated', '1', '', '0', 'P', 'Toughened Glass', '19-JUL-2017 15:29:05', '', '', '1', '', '20-JUL-2017 00:25:46', '-1', '', '', 'IN', 'FENQ', 'Toughened Glass', 'Glass: Stained Glass, Etched Glass, Laminated Glass & Others', '']
# ...

# %%
import csv
ifile  = open('BAN_SUPP_DATA.csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>10):
        break
# Out:
# ['FK_ETO_OFR_DISPLAY_ID', 'FK_GLUSR_USR_ID', 'FK_EMPLOYEE_ID', 'MAPPING_DATE', 'ETO_LEAD_SEARCH_KEYWORD', 'ETO_LEADSUPMAP_PROCESSED', 'ETO_LEAD_SUPPLIER_RANK', 'SD_DISPLAY_ID', 'SD_DATA_TYPE', 'ETO_LEAD_SUPPLIER_MAPPING_ID', 'ETO_LEAD_PRIME_MCAT', 'ETO_LEADSUPMAP_TYP', 'ETO_LEAD_SUPPLIER_DIST', 'ETO_LEAD_TOTAL_SUPP_COUNT']
#
#
# ['18663416159', '20782781', '59777', '01-JAN-2018 09:53:08', 'Palazzo Suit [T]', '8', '13', '16504814433', 'product', '3653870190', '181841', 'A', '8234', '', '']
#
#
# ['18663504095', '7690037', '59775', '01-JAN-2018 09:54:26', 'Canon Ink [T]', '8', '4', '12389368255', 'product', '3653880684', '35739', 'A', '8186', '', '']
#
#
# ['18663504095', '7690037', '59775', '01-JAN-2018 09:54:26', 'Canon Ink [T]', '8', '4', '12389368255', 'product', '3653880684', '35739', 'A', '8186', '', '']
#
#
# ['18663504095', '3450288', '59775', '01-JAN-2018 09:54:26', 'Canon Ink [T]', '8', '14', '4220890388', 'product', '3653880704', '35739', 'A', '7533', '', '']
#
#
# ...

# %%
import csv
ifile  = open('USER_MASTER (2).csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>2):
        break
# Out:
# ['GLUSR_USR_ID', 'GLUSR_USR_ADD1', 'GLUSR_USR_ADD2', 'GLUSR_USR_CITY', 'GLUSR_USR_STATE', 'FK_GL_COUNTRY_ISO', 'GLUSR_USR_ZIP', 'GLUSR_USR_YEAR_OF_ESTB', 'FK_GLUSR_TURNOVER_ID', 'GLUSR_USR_APPROV', 'GLUSR_USR_MODID', 'GLUSR_USR_IPADDRESS', 'FK_GL_STATE_ID', 'GLUSR_USR_STATE_OTHERS', 'GLUSR_USR_CITY_OTHERS', 'FCP_FLAG', 'FK_GLUSR_BIZ_IDS', 'GLUSR_USR_CUSTTYPE_ID', 'GLUSR_USR_CUSTTYPE_NAME', 'GLUSR_USR_CUSTTYPE_WEIGHT', 'GLUSR_USR_LONGITUDE', 'GLUSR_USR_LATITUDE', 'GLUSR_USR_LOCALITY', 'GLUSR_USR_LANDMARK', '']
#
#
# ['1145', 'No. 154, G. T. Road, South', '2nd Floor', 'Howrah', 'West Bengal', 'IN', '711102', '1993', '200', 'A', 'DIR', '192.168.2.90', '6501', '', '', '2', '10,20,30', '2', 'CATALOG', '699', '88.326031', '22.570149', 'G T Road', '', '']
#
#
# ['6363', 'E-15, Focal Point', '', 'Dera bassi', 'Punjab', 'IN', '140201', '2002', '200', 'A', 'FRL', '192.168.2.90', '6495', '', '', '2', '20,10,100', '1', 'TSCATALOG', '199', '76.855135', '30.609044', 'Focal Point', '', '']

# %%
import csv
ifile  = open('USER_PRODUCTS (1).csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>20):
        break
# Out:
# ['PC_ITEM_NAME', 'PC_ITEM_GLUSR_USR_ID', 'FK_GLCAT_MCAT_ID', 'ITEM_MAPPING_ISPRIME', '']
#
#
# ['Commercial Interior Designing Service', '19111989', '42049', '-1', '']
#
#
# ['Commercial Interior Designing Service', '19111989', '31028', '0', '']
#
#
# ['Commercial Interior Designing Service', '19111989', '31020', '0', '']
#
#
# ['Structural Glazing', '8327537', '38912', '-1', '']
#
#
# ['Metal Hair Beads', '498615', '11068', '-1', '']
#
#
# ['Gas Detectors', '4567725', '20966', '-1', '']
#
#
# ['Commercial Interior Designer Services', '19111989', '42049', '-1', '']
#
#
# ['Commercial Interior Designer Services', '19111989', '31028', '0', '']
#
#
# ['Commercial Interior Designer Services', '19111989', '31020', '0', '']
#
#
# ['Ceftazidime Sodium Injection', '14113623', '1466', '-1', '']
#
#
# ['Ceftazidime Sodium Injection', '14113623', '10149', '0', '']
#
#
# ['Industrial Valve', '4379972', '38309', '-1', '']
#
#
# ['Caustic Soda Flakes', '46373414', '3631', '-1', '']
#
#
# ...

# %%
import csv
ifile  = open('USER_MCAT_MAPP (2).csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>20):
        break
# Out:
# ['ETO_TRD_ALERT_ID', 'FK_GLUSR_USR_ID', 'FK_GLCAT_MCAT_ID', 'ETO_TRD_ALERT_DATE', 'ETO_TRD_ALERT_TYP', 'ETO_TRD_ALERT_LAST_SENT', 'ETO_TRD_ALERT_BY', 'ETO_TRD_ALERT_DISABLED_BY', 'ETO_TRD_ALERT_MODE', 'ETO_TRD_ALERT_RANK', 'ETO_TRD_ALERT_RANK_FLAG', 'IIL_MAIL_OPEN_DATE', 'ETO_TRD_ALERT_SCORE', 'ETO_TRD_ALERT_MOD_DATE', 'ETO_TRD_ALERT_RANK_CLICK', 'ETO_TRD_ALERT_RANK_SHORTLIST', 'ETO_TRD_ALERT_RANK_COMPOSITE', 'ETO_BL_ALERT_EMAIL_LIMIT', 'ETO_BL_ALERT_SMS_LIMIT', 'ETO_BL_ALERT_APP_NOTIFY_LIMIT', 'GLCAT_MCAT_NAME', 'GLUSR_USR_LOC_PREF', 'GLUSR_USR_CUSTTYPE_ID', '']
#
#
# ['61572501', '3804464', '13799', '06-JUN-2017 23:25:39', 'B', '', '0', '', '1', 'A', '', '06-JUN-2017 23:25:20', '10', '06-MAR-2018 00:45:59', '', '', 'D', '169', '168', '24', 'Clay Figure', '1', '1', '']
#
#
# ['61572516', '8775423', '29824', '06-JUN-2017 23:25:39', 'B', '', '0', '', '1', 'C', '', '06-JUN-2017 23:25:20', '0', '09-MAR-2018 00:47:40', '', '', 'D', '2', '168', '12', 'Grinding Belts', '2', '1', '']
#
#
# ...

# %%
import csv
ifile  = open('ETO_OFR_USR_SMS_ARCH_PAID2.csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>20):
        break
# Out:
# ['FK_GLUSR_USR_ID', '', 'FK_ETO_OFR_ID', '', 'ETO_OFR_USR_SEND_SMS_DATE', '', '']
#
#
# ['3960795', '', '16864764085', '', '03-oct-2017 19:37:16', '', '']
#
#
# ['2610822', '', '16864764085', '', '03-oct-2017 20:06:30', '', '']
#
#
# ['2610822', '', '16864764085', '', '03-oct-2017 20:06:30', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 16:50:55', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 16:50:55', '', '']
#
#
# ['3701605', '', '16864764085', '', '03-oct-2017 20:18:48', '', '']
#
#
# ['3701605', '', '16864764085', '', '03-oct-2017 20:18:48', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 19:07:58', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 19:07:58', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 14:15:25', '', '']
#
#
# ['36201426', '', '16779448234', '', '03-oct-2017 14:15:25', '', '']
#
#
# ['35030467', '', '16860474559', '', '03-oct-2017 16:36:10', '', '']
#
#
# ...

# %%
import csv
ifile  = open('OFR_MAPPING.csv', "r")
read = csv.reader(ifile, delimiter = "#")
i = 0
for row in read :
    i = i+1
    print (row)
    print("\n")
    if (i>2):
        break
# Out:
# ['05-DEC-2017 10:44:22', '18138130675', '68', '148633', '82143373', '148633', '']
#
#
# ['05-DEC-2017 10:44:22', '18138130675', '68', '18297', '82143374', '148633', '']
#
#
# ['05-DEC-2017 10:44:22', '18138130675', '68', '99410', '82143375', '148633', '']
